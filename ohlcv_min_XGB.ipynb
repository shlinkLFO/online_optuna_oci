# %%
# B3_Configurable_Minute_PerSymbol.py
# Predictor with Sliding Window, Per-Step HParam Tuning, and PTT
# Adapted for minute-level data from ohlcv.csv, processing per symbol.

import pandas as pd
import numpy as np
import time
import os
import warnings
import traceback
from datetime import datetime
import xgboost as xgb
import matplotlib.pyplot as plt

# Modeling Imports
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import GridSearchCV, StratifiedKFold, ParameterGrid
from sklearn.exceptions import UndefinedMetricWarning

# --- Suppress Warnings ---
warnings.filterwarnings('ignore', category=UndefinedMetricWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
warnings.filterwarnings('ignore', category=pd.errors.PerformanceWarning)
warnings.filterwarnings('ignore')

# ==============================================================================
# --- Configuration ---
# ==============================================================================

# --- Data ---
CSV_FILE_PATH = 'ohlcv.csv'
# N_ROWS_INPUT: Removed, processing all rows per symbol after filtering.

# --- Target Definition ---
PREDICTION_WINDOW_MINUTES = 4 * 60 # How many MINUTES ahead to predict (e.g., 24 hours)
TARGET_THRESHOLD_PCT = 3.5         # Target threshold for positive class (>= this value is 1)

# --- Backtesting Windowing (Defined in MINUTES) ---
# Example: 8 weeks training = 8 * 7 * 24 * 60 minutes
TRAIN_WINDOW_MINUTES = 48 * 60
STEP_MINUTES = 12 * 60             # Retrain/predict step size (e.g., daily = 24*60 minutes)
# Test window size as a fraction of the training window
TEST_WINDOW_FRACTION = 0.2         # e.g., 0.2 means test window is 20% of train window

# --- Model & Tuning ---
# Fixed XGBoost parameters (not tuned in grid search)
XGB_FIXED_PARAMS = {
    'learning_rate': 0.086,
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'use_label_encoder': False, # Deprecated, use False
    'random_state': 42,
    'reg_lambda': 4.0,         # L2 Regularization (Example value)
    'n_jobs': -1               # Use all available CPU cores
}

# Parameter grid for GridSearchCV (Keep combinations reasonable)
XGB_PARAM_GRID_TUNE = {
    'max_depth': [6, 7, 9],          # 3 options
    'n_estimators': [112, 147],       # 2 options
    'subsample': [0.83, 0.92],         # 2 options
    'colsample_bytree': [0.68, 0.72],  # 2 options
    'reg_alpha': [0.14, 0.26]         # L1 Regularization (2 options)
} # Total combinations: 3 * 2 * 2 * 2 * 2 = 48

# Probability Threshold Tuning Range
PROBABILITY_THRESHOLD_RANGE = (0.10, 0.90) # Start to end (end exclusive)
PROBABILITY_THRESHOLD_STEP = 0.05

# ==============================================================================
# --- Derived Variables (Do not change these directly) ---
# ==============================================================================
# Window sizes are now directly the number of rows (minutes)
TEST_WINDOW_MINUTES = max(1, int(TEST_WINDOW_FRACTION * TRAIN_WINDOW_MINUTES)) # Ensure at least 1 row
THRESHOLD_SEARCH_RANGE = np.arange(
    PROBABILITY_THRESHOLD_RANGE[0],
    PROBABILITY_THRESHOLD_RANGE[1],
    PROBABILITY_THRESHOLD_STEP
)
try:
    grid_combinations = len(list(ParameterGrid(XGB_PARAM_GRID_TUNE))) # Calculate grid size
except TypeError: # Handle case where grid might be None or empty
    grid_combinations = 1

# ==============================================================================
# --- Feature Engineering Functions (Minute Based) ---
# ==============================================================================
def garman_klass_volatility_min(o, h, l, c, window_min):
    with np.errstate(divide='ignore', invalid='ignore'):
        log_hl = np.log(h / l.replace(0, np.nan))
        log_co = np.log(c / o.replace(0, np.nan))
    gk = 0.5 * (log_hl**2) - (2 * np.log(2) - 1) * (log_co**2)
    gk = gk.fillna(0)
    # Use min_periods appropriate for potentially large windows
    min_p = max(1, window_min // 4) # Adjust min_periods heuristic if needed
    rm = gk.rolling(window_min, min_periods=min_p).mean()
    rm = rm.clip(lower=0)
    return np.sqrt(rm)

def parkinson_volatility_min(h, l, window_min):
    with np.errstate(divide='ignore', invalid='ignore'):
        log_hl_sq = np.log(h / l.replace(0, np.nan))**2
    log_hl_sq = log_hl_sq.fillna(0)
    min_p = max(1, window_min // 4) # Adjust min_periods heuristic if needed
    rs = log_hl_sq.rolling(window_min, min_periods=min_p).sum()
    f = 1 / (4 * np.log(2) * window_min) if window_min > 0 else 0
    return np.sqrt(f * rs)

def calculate_features_min(df_input):
    """Calculates features for minute-level data."""
    df = df_input.copy()
    base_cols_numeric = ['open', 'high', 'low', 'close', 'volumefrom', 'volumeto'] # Updated column names
    for col in base_cols_numeric:
        if col in df.columns: df[col] = pd.to_numeric(df[col], errors='coerce')
        else: print(f"Warning: Missing base column '{col}'"); df[col] = 0

    if df[['open', 'high', 'low', 'close']].isnull().any().any():
        print("Warning: OHLC NaNs found. Dropping rows.")
        df = df.dropna(subset=['open', 'high', 'low', 'close'])
    if df.empty:
        print("Error: Empty DF after initial OHLC NaN drop.")
        return df # Return empty df

    # --- Feature Calculations (MINUTE BASED) ---
    df['price_change_1m_temp'] = df['close'].pct_change(periods=1) # 1-minute change

    with np.errstate(divide='ignore', invalid='ignore'):
        df['price_range_pct'] = (df['high'] - df['low']) / df['close'].replace(0, np.nan) * 100
        df['oc_change_pct'] = (df['close'] - df['open']) / df['open'].replace(0, np.nan) * 100

    # --- Volatility (Windows in Minutes) ---
    # Example: 12 hours = 720 minutes, 3 hours = 180 minutes
    df['garman_klass_720m'] = garman_klass_volatility_min(df['open'], df['high'], df['low'], df['close'], 12 * 60)
    df['parkinson_180m'] = parkinson_volatility_min(df['high'], df['low'], 3 * 60)

    min_periods_rolling = 2 # Minimum periods for short rolling windows

    # --- MAs / STDs (Windows in Minutes) ---
    # Short term
    df['ma_180m'] = df['close'].rolling(3 * 60, min_periods=max(min_periods_rolling, (3*60)//4)).mean()
    df['rolling_std_180m'] = df['close'].rolling(3 * 60, min_periods=max(min_periods_rolling, (3*60)//4)).std()

    # Lag Features (Periods in Minutes)
    # Example lags: 3h, 6h, 12h, 24h, 2d, 3d, 7d
    lag_periods_price_min = [3*60, 6*60, 12*60, 24*60, 48*60, 72*60, 168*60]
    lag_periods_volume_min = [3*60, 6*60, 12*60, 24*60]

    for lag in lag_periods_price_min:
        df[f'lag_{lag}m_price_return'] = df['price_change_1m_temp'].shift(lag) * 100

    df['volume_return_1m'] = df['volumefrom'].pct_change(periods=1) * 100 # Use 'volumefrom'
    for lag in lag_periods_volume_min:
        df[f'lag_{lag}m_volume_return'] = df['volume_return_1m'].shift(lag)

    # Longer term MAs / STDs (Windows in Minutes)
    # Example periods: 6h, 12h, 24h, 2d, 3d, 7d
    ma_periods_min = [6*60, 12*60, 24*60, 48*60, 72*60, 168*60]
    std_periods_min = [6*60, 12*60, 24*60, 48*60, 72*60, 168*60]
    min_p_long = 50 # Example: require at least 50 points for longer averages

    for p in ma_periods_min:
        df[f'ma_{p}m'] = df['close'].rolling(p, min_periods=max(min_p_long, p//4)).mean()
    for p in std_periods_min:
        # Std of minute returns
        df[f'rolling_std_{p}m'] = df['price_change_1m_temp'].rolling(p, min_periods=max(min_p_long, p//4)).std() * 100 # Scaled

    # --- ATR (Windows in Minutes) ---
    df['prev_close'] = df['close'].shift(1)
    df['hml'] = df['high'] - df['low']
    df['hmpc'] = np.abs(df['high'] - df['prev_close'])
    df['lmpc'] = np.abs(df['low'] - df['prev_close'])
    df['tr'] = df[['hml', 'hmpc', 'lmpc']].max(axis=1)
    atr_periods_min = [14 * 60, 24 * 60, 48 * 60] # Example: 14h, 24h, 48h
    min_p_atr = 20 # Min periods for ATR

    for p in atr_periods_min:
        df[f'atr_{p}m'] = df['tr'].rolling(p, min_periods=max(min_p_atr, p//4)).mean()
    df = df.drop(columns=['prev_close', 'hml', 'hmpc', 'lmpc', 'tr'])

    # --- Ratio Features (using minute-based MAs/STDs) ---
    epsilon = 1e-9
    # Example: Close / MA_24h (1440 min), Close / MA_7d (10080 min)
    for p in [24*60, 168*60]:
        mc = f'ma_{p}m'
        df[f'close_div_ma_{p}m'] = df['close'] / (df[mc] + epsilon) if mc in df else np.nan

    # Example: MA_12h / MA_48h
    if 'ma_720m' in df and 'ma_2880m' in df: # 12h = 720m, 48h = 2880m
        df['ma720_div_ma2880'] = df['ma_720m'] / (df['ma_2880m'] + epsilon)
    else: df['ma720_div_ma2880'] = np.nan

    # Example: MA_24h / MA_7d
    if 'ma_1440m' in df and 'ma_10080m' in df: # 24h = 1440m, 7d = 10080m
        df['ma1440_div_ma10080'] = df['ma_1440m'] / (df['ma_10080m'] + epsilon)
    else: df['ma1440_div_ma10080'] = np.nan

    # Example: Std_12h / Std_72h
    if 'rolling_std_720m' in df and 'rolling_std_4320m' in df: # 12h=720m, 72h=4320m
        df['std720_div_std4320'] = df['rolling_std_720m'] / (df['rolling_std_4320m'] + epsilon)
    else: df['std720_div_std4320'] = np.nan

    # --- Interaction Features ---
    if 'price_range_pct' in df:
        df['volumefrom_x_range'] = df['volumefrom'] * df['price_range_pct'] # Use volumefrom
    else: df['volumefrom_x_range'] = np.nan

    # --- Transformation Features ---
    if 'rolling_std_180m' in df: # Use 3h = 180m STD
        df['rolling_std_180m_sq'] = df['rolling_std_180m']**2
    else: df['rolling_std_180m_sq'] = np.nan

    if 'price_change_1m_temp' in df:
        df['price_return_1m_sq'] = df['price_change_1m_temp']**2 * 10000 # Scale sq return
    else: df['price_return_1m_sq'] = np.nan

    if 'rolling_std_720m' in df: # Use 12h = 720m STD
        df['rolling_std_720m_sqrt'] = np.sqrt(df['rolling_std_720m'].clip(lower=0) + epsilon)
    else: df['rolling_std_720m_sqrt'] = np.nan

    # --- Cleanup Intermediate ---
    cols_to_drop_intermediate = ['price_change_1m_temp', 'volume_return_1m']
    df = df.drop(columns=[col for col in cols_to_drop_intermediate if col in df.columns])

    return df

# ==============================================================================
# --- Main Script Logic ---
# ==============================================================================

overall_start_time = time.time()

# --- 1. Load Data ---
print("--- Data Loading ---")
print(f"Loading data from: {CSV_FILE_PATH}")
try:
    # Read directly, parse timestamp
    df_full = pd.read_csv(CSV_FILE_PATH, parse_dates=['timestamp'])
    # Sort globally first
    df_full = df_full.sort_values(by=['symbol', 'timestamp'], ascending=True).reset_index(drop=True)
    print(f"Loaded {len(df_full)} rows for symbols: {df_full['symbol'].unique()}")
except FileNotFoundError: print(f"Error: {CSV_FILE_PATH} not found."); exit()
except Exception as e: print(f"Error loading data: {e}"); exit()

# --- Get unique symbols ---
unique_symbols = df_full['symbol'].unique()
all_symbol_results = {} # Store results per symbol

# --- Loop through each symbol ---
for symbol in unique_symbols:
    print(f"\n{'='*30} Processing Symbol: {symbol} {'='*30}")
    symbol_start_time = time.time()

    # Filter data for the current symbol
    df_symbol = df_full[df_full['symbol'] == symbol].copy()
    # Ensure it's sorted by time for this symbol (should be already, but double-check)
    df_symbol = df_symbol.sort_values(by='timestamp').reset_index(drop=True)
    print(f"Processing {len(df_symbol)} rows for {symbol}")

    if len(df_symbol) < TRAIN_WINDOW_MINUTES + STEP_MINUTES:
        print(f"Warning: Insufficient data for {symbol} ({len(df_symbol)} rows) for the initial training window ({TRAIN_WINDOW_MINUTES}) + step ({STEP_MINUTES}). Skipping symbol.")
        continue

    # --- 2. Feature Engineering (for this symbol) ---
    print(f"\n--- Feature Engineering for {symbol} ---")
    start_fe = time.time()
    df_symbol = calculate_features_min(df_symbol)
    if df_symbol.empty:
        print(f"Error: Feature calculation resulted in empty DataFrame for {symbol}. Skipping symbol.")
        continue
    print(f"Feature engineering for {symbol} complete. Took {time.time() - start_fe:.2f} seconds.")
    print(f"Columns after features: {df_symbol.shape[1]}")


    # --- 3. Define Target Variable (for this symbol) ---
    print("\n--- Target Definition ---")
    print(f"Defining target as {PREDICTION_WINDOW_MINUTES}m future return >= {TARGET_THRESHOLD_PCT}%...")
    target_col = f'target_return_{PREDICTION_WINDOW_MINUTES}m' # Dynamic target column name
    # Shift within the symbol's data
    df_symbol[target_col] = df_symbol['close'].shift(-PREDICTION_WINDOW_MINUTES).sub(df_symbol['close']).div(df_symbol['close'].replace(0, np.nan)).mul(100)

    # --- 4. Prepare Data for Modeling (for this symbol) ---
    print("\n--- Data Preparation ---")
    # Define base columns to exclude from features (using new names)
    base_cols_ohlcv = ['open', 'high', 'low', 'close', 'volumefrom', 'volumeto']
    # Columns to keep for indexing/reference, excluding target initially
    cols_to_keep_final = ['timestamp', 'symbol', target_col] # Use 'timestamp'
    potential_feature_cols = [col for col in df_symbol.columns if col not in cols_to_keep_final and col not in base_cols_ohlcv]

    # Select only numeric features among potential ones
    numeric_feature_cols = df_symbol[potential_feature_cols].select_dtypes(include=np.number).columns.tolist()
    final_feature_cols = numeric_feature_cols # Use all derived numeric features

    # Select final columns including features, target, and identifiers
    cols_to_select = final_feature_cols + [col for col in cols_to_keep_final if col in df_symbol.columns]
    df_model_ready = df_symbol[cols_to_select].copy()

    # --- NaN / Inf Handling ---
    # Drop columns with too many NaNs instead of dropping rows
    initial_cols = len(final_feature_cols)
    nan_threshold = 0.3  # Drop columns with more than 30% NaN values
    
    # Calculate NaN percentage for each feature column
    nan_percentages = df_model_ready[final_feature_cols].isna().mean()
    cols_to_drop = nan_percentages[nan_percentages > nan_threshold].index.tolist()
    
    if cols_to_drop:
        print(f"Dropping {len(cols_to_drop)} columns with >30% NaN values: {cols_to_drop}")
        df_model_ready = df_model_ready.drop(columns=cols_to_drop)
        final_feature_cols = [col for col in final_feature_cols if col not in cols_to_drop]
    
    # Now drop rows with NaNs in the remaining features or target
    initial_rows = len(df_model_ready)
    df_model_ready = df_model_ready.dropna(subset=final_feature_cols + [target_col])
    final_rows = len(df_model_ready)
    print(f"NaN Handling: Dropped {len(cols_to_drop)} columns with high NaN rate and {initial_rows - final_rows} rows with remaining NaNs.")

    # Check for infinites in numeric feature columns only
    numeric_cols_final_check = df_model_ready[final_feature_cols].select_dtypes(include=np.number).columns.tolist()
    if not numeric_cols_final_check:
         print(f"Error: No numeric feature columns found for {symbol} after NaN drop. Skipping.")
         continue

    inf_mask = np.isinf(df_model_ready[numeric_cols_final_check])
    inf_count = inf_mask.sum().sum()
    if inf_count > 0:
        print(f"Replacing {inf_count} infinites with NaN in features...")
        df_model_ready.replace([np.inf, -np.inf], np.nan, inplace=True)
        rows_b4 = len(df_model_ready)
        # Re-drop NaNs only if infinites were introduced in feature columns
        df_model_ready = df_model_ready.dropna(subset=final_feature_cols)
        print(f"Dropped {rows_b4 - len(df_model_ready)} more rows after Inf handling.")

    if df_model_ready.empty:
        print(f"Error: DataFrame empty after NaN/Inf handling for {symbol}. Skipping symbol.")
        continue

    # --- Final X, y, timestamps ---
    X = df_model_ready[final_feature_cols]
    y_binary = (df_model_ready[target_col] >= TARGET_THRESHOLD_PCT).astype(int)
    timestamps = df_model_ready['timestamp'] # Use the 'timestamp' column

    print(f"Final feature matrix shape for {symbol}: {X.shape}")
    print(f"Target vector shape for {symbol}: {y_binary.shape}")
    print(f"Using {len(final_feature_cols)} features.")
    # print(f"Feature list: {final_feature_cols}") # Uncomment to debug features

    # --- 5. SLIDING Window Backtesting (for this symbol) ---
    print(f"\n--- Starting SLIDING Window Backtest for {symbol} ---")
    print("!!! WARNING: This will be significantly slower due to GridSearchCV in each step !!!")
    if len(X) < TRAIN_WINDOW_MINUTES + STEP_MINUTES:
        print(f"Error: Not enough data for {symbol} ({len(X)}) for train window ({TRAIN_WINDOW_MINUTES}) + step ({STEP_MINUTES}). Skipping backtest for symbol.")
        continue

    # Reset storage for this symbol
    symbol_predictions_proba = []; symbol_actual = []; symbol_timestamps = []
    symbol_best_params = []
    num_steps = 0
    # Adjust end index for test window size
    start_index_loop = TRAIN_WINDOW_MINUTES
    end_index_loop = len(X) - TEST_WINDOW_MINUTES + 1 # Ensure test window fits

    print(f"Train Window: {TRAIN_WINDOW_MINUTES} mins, Step: {STEP_MINUTES} mins, Test Window: {TEST_WINDOW_MINUTES} mins, Tuning Grid Size: {grid_combinations}")
    loop_start_time = time.time()

    for i in range(start_index_loop, end_index_loop, STEP_MINUTES):
        step_start_time = time.time()
        train_idx_start = i - TRAIN_WINDOW_MINUTES
        train_idx_end = i
        test_idx_start = i
        test_idx_end = min(i + TEST_WINDOW_MINUTES, len(X)) # Ensure test end index is within bounds

        if test_idx_start >= test_idx_end: # Should not happen with len check above, but safety
            print(f"Stopping loop: Test window invalid ({test_idx_start} >= {test_idx_end}).")
            break

        # Get train and test sets for this step
        X_train_roll = X.iloc[train_idx_start : train_idx_end]
        y_train_roll = y_binary.iloc[train_idx_start : train_idx_end]
        X_test_roll = X.iloc[test_idx_start : test_idx_end]
        y_test_roll_actual_series = y_binary.iloc[test_idx_start : test_idx_end]
        step_timestamps = timestamps.iloc[test_idx_start : test_idx_end] # Timestamps for the test window
        current_timestamp = step_timestamps.iloc[0] # Timestamp for the start of the test window

        if X_train_roll.empty or len(np.unique(y_train_roll)) < 2:
            print(f"Warning: Skipping step starting at index {i} for {symbol}. Invalid training data (empty or single class).")
            continue

        print(f"\n--- {symbol} - Step {num_steps + 1} (Predicting window starting {current_timestamp}) ---")
        print(f"  Training indices: [{train_idx_start}:{train_idx_end-1}]; Testing indices: [{test_idx_start}:{test_idx_end-1}]")

        # --- Hyperparameter Tuning ---
        print(f"  Running GridSearchCV (cv=3, scoring='f1')...")
        grid_search_start_time = time.time()
        try:
            estimator = xgb.XGBClassifier(**XGB_FIXED_PARAMS)
            # Use StratifiedKFold with shuffle, random_state tied to step for reproducibility if desired
            cv_strategy = StratifiedKFold(n_splits=3, shuffle=True, random_state=i)
            grid_search = GridSearchCV(
                estimator=estimator, param_grid=XGB_PARAM_GRID_TUNE, scoring='f1',
                cv=cv_strategy, n_jobs=-1, verbose=0
            )
            grid_search.fit(X_train_roll, y_train_roll) # Fit GridSearch
            best_params_step = grid_search.best_params_
            best_score_step = grid_search.best_score_
            print(f"  GridSearchCV finished in {time.time() - grid_search_start_time:.2f}s.")
            print(f"  Best Params: {best_params_step}, Best CV F1: {best_score_step:.4f}")
            symbol_best_params.append({'step': num_steps + 1, 'params': best_params_step, 'cv_f1': best_score_step})

            # --- Fit final model for the step ---
            final_model_params = {**XGB_FIXED_PARAMS, **best_params_step}
            model_roll = xgb.XGBClassifier(**final_model_params)
            model_roll.fit(X_train_roll, y_train_roll, verbose=False) # Fit final model

            # --- Predict probabilities for the test window ---
            prob_roll_window = model_roll.predict_proba(X_test_roll)[:, 1] # Prob of positive class

            # --- Store results for this symbol ---
            symbol_predictions_proba.extend(prob_roll_window)
            symbol_actual.extend(y_test_roll_actual_series.tolist())
            symbol_timestamps.extend(step_timestamps.tolist())
            num_steps += 1

        except Exception as e_step:
            print(f"!! Error during GridSearch/Fit/Predict at step starting {i} for {symbol}: {e_step}")
            # traceback.print_exc() # Uncomment for detailed error
            continue # Skip to next step

        step_end_time = time.time()
        print(f"  Step {num_steps} finished in {step_end_time - step_start_time:.2f}s total.")

    loop_end_time = time.time()
    print(f"\nBacktesting loop for {symbol} finished. Completed {num_steps} steps (each predicting up to {TEST_WINDOW_MINUTES} points) in {(loop_end_time - loop_start_time)/60:.2f} minutes.")

    # --- 6. Evaluate Backtesting Results with PTT (for this symbol) ---
    if num_steps > 0 and len(symbol_predictions_proba) == len(symbol_actual):
        print(f"\n--- Evaluating Results for {symbol} with Probability Threshold Tuning ---")
        print(f"Threshold search range: {THRESHOLD_SEARCH_RANGE}")
        best_threshold = 0.5; best_f1_thresh = -1.0
        results_per_threshold = {}
        probabilities_np = np.array(symbol_predictions_proba)
        actual_np = np.array(symbol_actual)

        for t in THRESHOLD_SEARCH_RANGE:
            predictions_thresh = (probabilities_np >= t).astype(int)
            # Use same robust metric calculation as before
            if np.sum(actual_np) == 0 and np.sum(predictions_thresh) == 0: acc_t, pre_t, rec_t, f1_t = 1.0, 1.0, 1.0, 1.0
            elif np.sum(actual_np) > 0 and np.sum(predictions_thresh) == 0: acc_t = accuracy_score(actual_np, predictions_thresh); pre_t, rec_t, f1_t = 0.0, 0.0, 0.0
            elif np.sum(actual_np) == 0 and np.sum(predictions_thresh) > 0: acc_t = accuracy_score(actual_np, predictions_thresh); pre_t, rec_t, f1_t = 0.0, 0.0, 0.0
            else:
                 acc_t = accuracy_score(actual_np, predictions_thresh)
                 pre_t = precision_score(actual_np, predictions_thresh, zero_division=0)
                 rec_t = recall_score(actual_np, predictions_thresh, zero_division=0)
                 f1_t = f1_score(actual_np, predictions_thresh, zero_division=0)

            results_per_threshold[round(t, 2)] = {'f1': f1_t, 'acc': acc_t, 'pre': pre_t, 'rec': rec_t}
            # Select best threshold based on F1 score
            if f1_t >= best_f1_thresh:
                 # Tie-breaking: prefer threshold closer to 0.5 if F1 is equal
                 if f1_t > best_f1_thresh or abs(t - 0.5) < abs(best_threshold - 0.5):
                      best_f1_thresh = f1_t
                      best_threshold = t

        print(f"\nBest Threshold for {symbol} found: {best_threshold:.2f} (Yielding F1 Score: {best_f1_thresh:.4f})")

        # Calculate final metrics using the best threshold for this symbol
        final_predictions_optimized = (probabilities_np >= best_threshold).astype(int)
        final_accuracy = accuracy_score(actual_np, final_predictions_optimized)
        final_precision = precision_score(actual_np, final_predictions_optimized, zero_division=0)
        final_recall = recall_score(actual_np, final_predictions_optimized, zero_division=0)
        final_f1 = f1_score(actual_np, final_predictions_optimized, zero_division=0)

        print(f"\n--- Final Performance Metrics for {symbol} (Optimized Threshold) ---")
        print(f"Target: {PREDICTION_WINDOW_MINUTES}m return >= {TARGET_THRESHOLD_PCT}%")
        print(f"Windowing: Train={TRAIN_WINDOW_MINUTES}m, Step={STEP_MINUTES}m, Test Window={TEST_WINDOW_MINUTES}m")
        print(f"Total Individual Predictions Evaluated: {len(actual_np)}")
        print(f"Overall Accuracy:  {final_accuracy:.4f}")
        print(f"Overall Precision: {final_precision:.4f}")
        print(f"Overall Recall:    {final_recall:.4f}")
        print(f"Overall F1 Score:  {final_f1:.4f}")

        if 0.5 in results_per_threshold:
            res_def = results_per_threshold[0.5]
            print(f"(Compare: Default 0.5 Thresh -> F1:{res_def['f1']:.4f}, Acc:{res_def['acc']:.4f}, Pre:{res_def['pre']:.4f}, Rec:{res_def['rec']:.4f})")

        # Store results
        all_symbol_results[symbol] = {
            'probabilities': probabilities_np,
            'actuals': actual_np,
            'timestamps': symbol_timestamps,
            'best_threshold': best_threshold,
            'metrics_optimized': {'acc': final_accuracy, 'pre': final_precision, 'rec': final_recall, 'f1': final_f1},
            'metrics_default_0.5': results_per_threshold.get(0.5, {}),
            'best_params_per_step': symbol_best_params,
            'results_per_threshold': results_per_threshold
        }

        # --- 7. Plot Cumulative Accuracy (for this symbol) ---
        print(f"\nPlotting cumulative accuracy for {symbol} (optimized threshold)...")
        if len(symbol_timestamps) != len(actual_np):
             print(f"Warning: Timestamp length mismatch for {symbol}. Skipping plot.")
        else:
            try:
                cumulative_accuracy_list_optimized = (np.cumsum(final_predictions_optimized == actual_np) / np.arange(1, len(actual_np) + 1))
                plt.figure(figsize=(14, 7))
                plt.plot(symbol_timestamps, cumulative_accuracy_list_optimized, marker='.', linestyle='-', markersize=1, alpha=0.7, label=f'Cumulative Accuracy ({symbol})') # Very small markers

                # Rolling accuracy can be very noisy on minute data - use a large window or skip
                rolling_window_plot_size = max(TEST_WINDOW_MINUTES * 5, 60 * 24) # e.g., 5 test windows or 1 day
                if len(actual_np) > rolling_window_plot_size:
                     results_df = pd.DataFrame({
                         'correct': (final_predictions_optimized == actual_np).astype(int)
                     }, index=pd.to_datetime(symbol_timestamps))
                     # Use a time-based window if timestamps are regular, otherwise integer window
                     try:
                         rolling_acc = results_df['correct'].rolling(window=f'{rolling_window_plot_size}Min').mean() # Try time window first
                     except:
                         rolling_acc = results_df['correct'].rolling(window=rolling_window_plot_size).mean() # Fallback to row window

                     plt.plot(rolling_acc.index, rolling_acc, linestyle='--', color='red', label=f'Rolling Acc ({rolling_window_plot_size} min window)')


                plt.title(f'{symbol} Backtest (Train:{TRAIN_WINDOW_MINUTES}m, Step:{STEP_MINUTES}m, Test:{TEST_WINDOW_MINUTES}m) - Best Thresh: {best_threshold:.2f}')
                plt.xlabel('Timestamp'); plt.ylabel('Accuracy')
                min_y_plot = max(0.0, np.min(cumulative_accuracy_list_optimized) - 0.05 if len(cumulative_accuracy_list_optimized)>0 else 0.4)
                max_y_plot = min(1.0, np.max(cumulative_accuracy_list_optimized) + 0.05 if len(cumulative_accuracy_list_optimized)>0 else 0.8)
                # Avoid overly tight y-limits if accuracy is stable
                if max_y_plot - min_y_plot < 0.1:
                    mid_point = (max_y_plot + min_y_plot) / 2
                    min_y_plot = max(0.0, mid_point - 0.05)
                    max_y_plot = min(1.0, mid_point + 0.05)
                plt.ylim(min_y_plot, max_y_plot)

                plt.grid(True, linestyle='--', alpha=0.6); plt.legend(); plt.xticks(rotation=30, ha='right'); plt.tight_layout()
                # Save plot instead of showing directly in a loop
                plot_filename = f"backtest_accuracy_{symbol}.png"
                plt.savefig(plot_filename)
                print(f"Saved accuracy plot to {plot_filename}")
                plt.close() # Close the figure to avoid displaying multiple plots at the end
                # plt.show() # Uncomment if you want interactive plots (will pause script)

            except Exception as e_plot: print(f"Error plotting for {symbol}: {e_plot}")

    else:
        print(f"No predictions were made/stored for {symbol}, cannot evaluate or plot.")
        all_symbol_results[symbol] = None # Mark as failed/skipped

    symbol_end_time = time.time()
    print(f"\nFinished processing {symbol} in {(symbol_end_time - symbol_start_time)/60:.2f} minutes.")


# --- End of Symbol Loop ---

print(f"\n{'='*30} Overall Script Finished {'='*30}")
overall_end_time = time.time()
print(f"Total execution time: {(overall_end_time - overall_start_time)/60:.2f} minutes.")

# You can access results like this:
# print(all_symbol_results['BTC']['metrics_optimized'])
# print(all_symbol_results['SOL']['best_threshold'])
# Out:
# --- Data Loading ---
# Loading data from: ohlcv.csv
# Loaded 45164 rows for symbols: ['BTC' 'SOL']
#
# ============================== Processing Symbol: BTC ==============================
# Processing 22582 rows for BTC
#
# --- Feature Engineering for BTC ---
# Feature engineering for BTC complete. Took 0.03 seconds.
# Columns after features: 49
#
# --- Target Definition ---
# Defining target as 720m future return >= 2.5%...
#
# --- Data Preparation ---
# NaN Handling: Dropped 10801 rows with NaNs in features or target.
# Final feature matrix shape for BTC: (11781, 41)
# Target vector shape for BTC: (11781,)
# Using 41 features.
#
# --- Starting SLIDING Window Backtest for BTC ---
# !!! WARNING: This will be significantly slower due to GridSearchCV in each step !!!
# Train Window: 1440 mins, Step: 60 mins, Test Window: 288 mins, Tuning Grid Size: 48
#
# --- BTC - Step 1 (Predicting window starting 2025-04-11 01:01:00) ---
#   Training indices: [0:1439]; Testing indices: [1440:1727]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 4.46s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9839
#   Step 1 finished in 4.52s total.
#
# --- BTC - Step 2 (Predicting window starting 2025-04-11 02:01:00) ---
#   Training indices: [60:1499]; Testing indices: [1500:1787]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.60s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9839
#   Step 2 finished in 1.66s total.
#
# --- BTC - Step 3 (Predicting window starting 2025-04-11 03:01:00) ---
#   Training indices: [120:1559]; Testing indices: [1560:1847]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.76s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.9893
#   Step 3 finished in 1.83s total.
#
# --- BTC - Step 4 (Predicting window starting 2025-04-11 04:01:00) ---
#   Training indices: [180:1619]; Testing indices: [1620:1907]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.90s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9833
#   Step 4 finished in 1.96s total.
#
# --- BTC - Step 5 (Predicting window starting 2025-04-11 05:01:00) ---
#   Training indices: [240:1679]; Testing indices: [1680:1967]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.05s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9795
#   Step 5 finished in 2.13s total.
#
# --- BTC - Step 6 (Predicting window starting 2025-04-11 06:01:00) ---
#   Training indices: [300:1739]; Testing indices: [1740:2027]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.05s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9824
#   Step 6 finished in 2.12s total.
#
# --- BTC - Step 7 (Predicting window starting 2025-04-11 07:01:00) ---
#   Training indices: [360:1799]; Testing indices: [1800:2087]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.08s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9869
#   Step 7 finished in 2.17s total.
#
# --- BTC - Step 8 (Predicting window starting 2025-04-11 08:01:00) ---
#   Training indices: [420:1859]; Testing indices: [1860:2147]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.10s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.83}, Best CV F1: 0.9846
#   Step 8 finished in 2.17s total.
#
# --- BTC - Step 9 (Predicting window starting 2025-04-11 09:01:00) ---
#   Training indices: [480:1919]; Testing indices: [1920:2207]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.09s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9870
#   Step 9 finished in 2.17s total.
#
# --- BTC - Step 10 (Predicting window starting 2025-04-11 10:01:00) ---
#   Training indices: [540:1979]; Testing indices: [1980:2267]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.20s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 7, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9868
#   Step 10 finished in 2.27s total.
#
# --- BTC - Step 11 (Predicting window starting 2025-04-11 11:01:00) ---
#   Training indices: [600:2039]; Testing indices: [2040:2327]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.20s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 7, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.9892
#   Step 11 finished in 2.27s total.
#
# --- BTC - Step 12 (Predicting window starting 2025-04-11 12:01:00) ---
#   Training indices: [660:2099]; Testing indices: [2100:2387]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.26s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.26, 'subsample': 0.83}, Best CV F1: 0.9852
#   Step 12 finished in 2.36s total.
#
# --- BTC - Step 13 (Predicting window starting 2025-04-11 13:01:00) ---
#   Training indices: [720:2159]; Testing indices: [2160:2447]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.19s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9860
#   Step 13 finished in 2.26s total.
#
# --- BTC - Step 14 (Predicting window starting 2025-04-11 14:01:00) ---
#   Training indices: [780:2219]; Testing indices: [2220:2507]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.26s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9893
#   Step 14 finished in 2.33s total.
#
# --- BTC - Step 15 (Predicting window starting 2025-04-11 15:01:00) ---
#   Training indices: [840:2279]; Testing indices: [2280:2567]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.21s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9835
#   Step 15 finished in 2.31s total.
#
# --- BTC - Step 16 (Predicting window starting 2025-04-11 16:01:00) ---
#   Training indices: [900:2339]; Testing indices: [2340:2627]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.20s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.9866
#   Step 16 finished in 2.28s total.
#
# --- BTC - Step 17 (Predicting window starting 2025-04-11 17:01:00) ---
#   Training indices: [960:2399]; Testing indices: [2400:2687]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.94s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9930
#   Step 17 finished in 2.00s total.
#
# --- BTC - Step 18 (Predicting window starting 2025-04-11 18:01:00) ---
#   Training indices: [1020:2459]; Testing indices: [2460:2747]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.91s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.26, 'subsample': 0.83}, Best CV F1: 0.9879
#   Step 18 finished in 1.98s total.
#
# --- BTC - Step 19 (Predicting window starting 2025-04-11 19:01:00) ---
#   Training indices: [1080:2519]; Testing indices: [2520:2807]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.89s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.83}, Best CV F1: 0.9853
#   Step 19 finished in 1.94s total.
#
# --- BTC - Step 20 (Predicting window starting 2025-04-11 20:01:00) ---
#   Training indices: [1140:2579]; Testing indices: [2580:2867]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.74s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9921
#   Step 20 finished in 1.81s total.
#
# --- BTC - Step 21 (Predicting window starting 2025-04-11 21:01:00) ---
#   Training indices: [1200:2639]; Testing indices: [2640:2927]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.70s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9921
#   Step 21 finished in 1.76s total.
#
# --- BTC - Step 22 (Predicting window starting 2025-04-11 22:01:00) ---
#   Training indices: [1260:2699]; Testing indices: [2700:2987]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.62s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9944
#   Step 22 finished in 1.68s total.
#
# --- BTC - Step 23 (Predicting window starting 2025-04-11 23:01:00) ---
#   Training indices: [1320:2759]; Testing indices: [2760:3047]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.53s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9876
#   Step 23 finished in 1.58s total.
#
# --- BTC - Step 24 (Predicting window starting 2025-04-12 00:01:00) ---
#   Training indices: [1380:2819]; Testing indices: [2820:3107]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.57s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.9845
#   Step 24 finished in 1.63s total.
#
# --- BTC - Step 25 (Predicting window starting 2025-04-12 01:01:00) ---
#   Training indices: [1440:2879]; Testing indices: [2880:3167]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.54s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9901
#   Step 25 finished in 1.59s total.
#
# --- BTC - Step 26 (Predicting window starting 2025-04-12 02:01:00) ---
#   Training indices: [1500:2939]; Testing indices: [2940:3227]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.53s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.83}, Best CV F1: 0.9881
#   Step 26 finished in 1.58s total.
#
# --- BTC - Step 27 (Predicting window starting 2025-04-12 03:01:00) ---
#   Training indices: [1560:2999]; Testing indices: [3000:3287]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.44s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9891
#   Step 27 finished in 1.48s total.
#
# --- BTC - Step 28 (Predicting window starting 2025-04-12 04:01:00) ---
#   Training indices: [1620:3059]; Testing indices: [3060:3347]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.69s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.26, 'subsample': 0.83}, Best CV F1: 0.9781
#   Step 28 finished in 1.76s total.
#
# --- BTC - Step 29 (Predicting window starting 2025-04-12 05:01:00) ---
#   Training indices: [1680:3119]; Testing indices: [3120:3407]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.62s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9726
#   Step 29 finished in 1.68s total.
#
# --- BTC - Step 30 (Predicting window starting 2025-04-12 06:01:00) ---
#   Training indices: [1740:3179]; Testing indices: [3180:3467]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.51s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9635
#   Step 30 finished in 1.57s total.
#
# --- BTC - Step 31 (Predicting window starting 2025-04-12 07:01:00) ---
#   Training indices: [1800:3239]; Testing indices: [3240:3527]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.59s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.9576
#   Step 31 finished in 1.64s total.
#
# --- BTC - Step 32 (Predicting window starting 2025-04-12 08:01:00) ---
#   Training indices: [1860:3299]; Testing indices: [3300:3587]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.50s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9336
#   Step 32 finished in 1.55s total.
#
# --- BTC - Step 33 (Predicting window starting 2025-04-12 09:01:00) ---
#   Training indices: [1920:3359]; Testing indices: [3360:3647]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.63s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.83}, Best CV F1: 0.7724
#   Step 33 finished in 1.70s total.
#
# --- BTC - Step 34 (Predicting window starting 2025-04-12 10:01:00) ---
#   Training indices: [1980:3419]; Testing indices: [3420:3707]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.42s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.7569
#   Step 34 finished in 1.49s total.
#
# --- BTC - Step 35 (Predicting window starting 2025-04-12 11:01:00) ---
#   Training indices: [2040:3479]; Testing indices: [3480:3767]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.68s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 7, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.7114
#   Step 35 finished in 1.75s total.
#
# --- BTC - Step 36 (Predicting window starting 2025-04-12 12:01:00) ---
#   Training indices: [2100:3539]; Testing indices: [3540:3827]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.66s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 7, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.7679
#   Step 36 finished in 1.71s total.
#
# --- BTC - Step 37 (Predicting window starting 2025-04-12 13:01:00) ---
#   Training indices: [2160:3599]; Testing indices: [3600:3887]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.71s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.6960
#   Step 37 finished in 1.76s total.
#
# --- BTC - Step 38 (Predicting window starting 2025-04-12 14:01:00) ---
#   Training indices: [2220:3659]; Testing indices: [3660:3947]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.76s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.6778
#   Step 38 finished in 1.83s total.
#
# --- BTC - Step 39 (Predicting window starting 2025-04-12 15:01:00) ---
#   Training indices: [2280:3719]; Testing indices: [3720:4007]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.86s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.7178
#   Step 39 finished in 1.95s total.
#
# --- BTC - Step 40 (Predicting window starting 2025-04-12 16:01:00) ---
#   Training indices: [2340:3779]; Testing indices: [3780:4067]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.85s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.6701
#   Step 40 finished in 1.92s total.
#
# --- BTC - Step 41 (Predicting window starting 2025-04-12 17:01:00) ---
#   Training indices: [2400:3839]; Testing indices: [3840:4127]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.85s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.6928
#   Step 41 finished in 1.92s total.
#
# --- BTC - Step 42 (Predicting window starting 2025-04-12 18:01:00) ---
#   Training indices: [2460:3899]; Testing indices: [3900:4187]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.86s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 9, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.7130
#   Step 42 finished in 1.94s total.
#
# --- BTC - Step 43 (Predicting window starting 2025-04-12 19:01:00) ---
#   Training indices: [2520:3959]; Testing indices: [3960:4247]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.86s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 7, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.6892
#   Step 43 finished in 1.96s total.
#
# --- BTC - Step 44 (Predicting window starting 2025-04-12 20:01:00) ---
#   Training indices: [2580:4019]; Testing indices: [4020:4307]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.82s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.6084
#   Step 44 finished in 1.87s total.
#
# --- BTC - Step 45 (Predicting window starting 2025-04-12 21:01:00) ---
#   Training indices: [2640:4079]; Testing indices: [4080:4367]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.87s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 7, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.7108
#   Step 45 finished in 1.93s total.
#
# --- BTC - Step 46 (Predicting window starting 2025-04-12 22:01:00) ---
#   Training indices: [2700:4139]; Testing indices: [4140:4427]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.84s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 7, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.83}, Best CV F1: 0.6782
#   Step 46 finished in 1.90s total.
#
# --- BTC - Step 47 (Predicting window starting 2025-04-12 23:01:00) ---
#   Training indices: [2760:4199]; Testing indices: [4200:4487]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.89s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 7, 'n_estimators': 147, 'reg_alpha': 0.26, 'subsample': 0.83}, Best CV F1: 0.7199
#   Step 47 finished in 1.99s total.
#
# --- BTC - Step 48 (Predicting window starting 2025-04-13 00:01:00) ---
#   Training indices: [2820:4259]; Testing indices: [4260:4547]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.82s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 7, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.83}, Best CV F1: 0.6988
#   Step 48 finished in 1.89s total.
#
# --- BTC - Step 49 (Predicting window starting 2025-04-13 01:01:00) ---
#   Training indices: [2880:4319]; Testing indices: [4320:4607]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.81s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.6917
#   Step 49 finished in 1.88s total.
#
# --- BTC - Step 50 (Predicting window starting 2025-04-13 02:01:00) ---
#   Training indices: [2940:4379]; Testing indices: [4380:4667]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.84s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.7260
#   Step 50 finished in 1.91s total.
#
# --- BTC - Step 51 (Predicting window starting 2025-04-13 03:01:00) ---
#   Training indices: [3000:4439]; Testing indices: [4440:4727]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.86s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.6762
#   Step 51 finished in 1.94s total.
#
# --- BTC - Step 52 (Predicting window starting 2025-04-13 04:01:00) ---
#   Training indices: [3060:4499]; Testing indices: [4500:4787]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.67s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.6564
#   Step 52 finished in 1.73s total.
#
# --- BTC - Step 53 (Predicting window starting 2025-04-13 05:01:00) ---
#   Training indices: [3120:4559]; Testing indices: [4560:4847]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.60s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.7123
#   Step 53 finished in 1.66s total.
#
# --- BTC - Step 54 (Predicting window starting 2025-04-13 06:01:00) ---
#   Training indices: [3180:4619]; Testing indices: [4620:4907]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.61s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.7569
#   Step 54 finished in 1.68s total.
#
# --- BTC - Step 55 (Predicting window starting 2025-04-13 07:01:00) ---
#   Training indices: [3240:4679]; Testing indices: [4680:4967]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.53s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.7000
#   Step 55 finished in 1.58s total.
#
# --- BTC - Step 56 (Predicting window starting 2025-04-13 08:01:00) ---
#   Training indices: [3300:4739]; Testing indices: [4740:5027]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.56s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.7095
#   Step 56 finished in 1.63s total.
#
# --- BTC - Step 57 (Predicting window starting 2025-04-13 09:01:00) ---
#   Training indices: [3360:4799]; Testing indices: [4800:5087]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.37s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.26, 'subsample': 0.83}, Best CV F1: 0.7722
#   Step 57 finished in 1.43s total.
#
# --- BTC - Step 58 (Predicting window starting 2025-04-13 10:01:00) ---
#   Training indices: [3420:4859]; Testing indices: [4860:5147]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.38s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.8519
#   Step 58 finished in 1.44s total.
#
# --- BTC - Step 59 (Predicting window starting 2025-04-13 11:01:00) ---
#   Training indices: [3480:4919]; Testing indices: [4920:5207]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.01s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.0000
#   Step 59 finished in 1.06s total.
#
# --- BTC - Step 60 (Predicting window starting 2025-04-13 12:01:00) ---
#   Training indices: [3540:4979]; Testing indices: [4980:5267]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.05s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.0000
#   Step 60 finished in 1.09s total.
#
# --- BTC - Step 61 (Predicting window starting 2025-04-13 13:01:00) ---
#   Training indices: [3600:5039]; Testing indices: [5040:5327]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 0.98s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.4444
#   Step 61 finished in 1.02s total.
# Warning: Skipping step starting at index 5100 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 5160 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 5220 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 5280 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 5340 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 5400 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 5460 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 5520 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 5580 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 5640 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 5700 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 5760 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 5820 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 5880 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 5940 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 6000 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 6060 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 6120 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 6180 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 6240 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 6300 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 6360 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 6420 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 6480 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 6540 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 6600 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 6660 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 6720 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 6780 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 6840 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 6900 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 6960 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 7020 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 7080 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 7140 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 7200 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 7260 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 7320 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 7380 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 7440 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 7500 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 7560 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 7620 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 7680 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 7740 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 7800 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 7860 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 7920 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 7980 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 8040 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 8100 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 8160 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 8220 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 8280 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 8340 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 8400 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 8460 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 8520 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 8580 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 8640 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 8700 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 8760 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 8820 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 8880 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 8940 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 9000 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 9060 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 9120 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 9180 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 9240 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 9300 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 9360 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 9420 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 9480 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 9540 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 9600 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 9660 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 9720 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 9780 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 9840 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 9900 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 9960 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 10020 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 10080 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 10140 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 10200 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 10260 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 10320 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 10380 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 10440 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 10500 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 10560 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 10620 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 10680 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 10740 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 10800 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 10860 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 10920 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 10980 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 11040 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 11100 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 11160 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 11220 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 11280 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 11340 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 11400 for BTC. Invalid training data (empty or single class).
# Warning: Skipping step starting at index 11460 for BTC. Invalid training data (empty or single class).
#
# Backtesting loop for BTC finished. Completed 61 steps (each predicting up to 288 points) in 1.89 minutes.
#
# --- Evaluating Results for BTC with Probability Threshold Tuning ---
# Threshold search range: [0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65 0.7  0.75
#  0.8  0.85]
#
# Best Threshold for BTC found: 0.25 (Yielding F1 Score: 0.4350)
#
# --- Final Performance Metrics for BTC (Optimized Threshold) ---
# Target: 720m return >= 2.5%
# Windowing: Train=1440m, Step=60m, Test Window=288m
# Total Individual Predictions Evaluated: 17568
# Overall Accuracy:  0.8786
# Overall Precision: 0.4003
# Overall Recall:    0.4762
# Overall F1 Score:  0.4350
# (Compare: Default 0.5 Thresh -> F1:0.4088, Acc:0.8946, Pre:0.4549, Rec:0.3712)
#
# Plotting cumulative accuracy for BTC (optimized threshold)...
# Saved accuracy plot to backtest_accuracy_BTC.png
#
# Finished processing BTC in 1.90 minutes.
#
# ============================== Processing Symbol: SOL ==============================
# Processing 22582 rows for SOL
#
# --- Feature Engineering for SOL ---
# Feature engineering for SOL complete. Took 0.03 seconds.
# Columns after features: 49
#
# --- Target Definition ---
# Defining target as 720m future return >= 2.5%...
#
# --- Data Preparation ---
# NaN Handling: Dropped 10801 rows with NaNs in features or target.
# Final feature matrix shape for SOL: (11781, 41)
# Target vector shape for SOL: (11781,)
# Using 41 features.
#
# --- Starting SLIDING Window Backtest for SOL ---
# !!! WARNING: This will be significantly slower due to GridSearchCV in each step !!!
# Train Window: 1440 mins, Step: 60 mins, Test Window: 288 mins, Tuning Grid Size: 48
#
# --- SOL - Step 1 (Predicting window starting 2025-04-11 01:01:00) ---
#   Training indices: [0:1439]; Testing indices: [1440:1727]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.04s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9983
#   Step 1 finished in 1.08s total.
#
# --- SOL - Step 2 (Predicting window starting 2025-04-11 02:01:00) ---
#   Training indices: [60:1499]; Testing indices: [1500:1787]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.05s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9984
#   Step 2 finished in 1.10s total.
#
# --- SOL - Step 3 (Predicting window starting 2025-04-11 03:01:00) ---
#   Training indices: [120:1559]; Testing indices: [1560:1847]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.08s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9979
#   Step 3 finished in 1.12s total.
#
# --- SOL - Step 4 (Predicting window starting 2025-04-11 04:01:00) ---
#   Training indices: [180:1619]; Testing indices: [1620:1907]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.03s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9980
#   Step 4 finished in 1.08s total.
#
# --- SOL - Step 5 (Predicting window starting 2025-04-11 05:01:00) ---
#   Training indices: [240:1679]; Testing indices: [1680:1967]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.06s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9988
#   Step 5 finished in 1.10s total.
#
# --- SOL - Step 6 (Predicting window starting 2025-04-11 06:01:00) ---
#   Training indices: [300:1739]; Testing indices: [1740:2027]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.05s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9989
#   Step 6 finished in 1.10s total.
#
# --- SOL - Step 7 (Predicting window starting 2025-04-11 07:01:00) ---
#   Training indices: [360:1799]; Testing indices: [1800:2087]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.05s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9989
#   Step 7 finished in 1.10s total.
#
# --- SOL - Step 8 (Predicting window starting 2025-04-11 08:01:00) ---
#   Training indices: [420:1859]; Testing indices: [1860:2147]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.07s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9985
#   Step 8 finished in 1.11s total.
#
# --- SOL - Step 9 (Predicting window starting 2025-04-11 09:01:00) ---
#   Training indices: [480:1919]; Testing indices: [1920:2207]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.05s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9986
#   Step 9 finished in 1.09s total.
#
# --- SOL - Step 10 (Predicting window starting 2025-04-11 10:01:00) ---
#   Training indices: [540:1979]; Testing indices: [1980:2267]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.31s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9969
#   Step 10 finished in 1.36s total.
#
# --- SOL - Step 11 (Predicting window starting 2025-04-11 11:01:00) ---
#   Training indices: [600:2039]; Testing indices: [2040:2327]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.55s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9943
#   Step 11 finished in 1.61s total.
#
# --- SOL - Step 12 (Predicting window starting 2025-04-11 12:01:00) ---
#   Training indices: [660:2099]; Testing indices: [2100:2387]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.65s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 7, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9944
#   Step 12 finished in 1.70s total.
#
# --- SOL - Step 13 (Predicting window starting 2025-04-11 13:01:00) ---
#   Training indices: [720:2159]; Testing indices: [2160:2447]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.69s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.9900
#   Step 13 finished in 1.75s total.
#
# --- SOL - Step 14 (Predicting window starting 2025-04-11 14:01:00) ---
#   Training indices: [780:2219]; Testing indices: [2220:2507]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.82s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.26, 'subsample': 0.83}, Best CV F1: 0.9910
#   Step 14 finished in 1.89s total.
#
# --- SOL - Step 15 (Predicting window starting 2025-04-11 15:01:00) ---
#   Training indices: [840:2279]; Testing indices: [2280:2567]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.83s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 7, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9922
#   Step 15 finished in 1.89s total.
#
# --- SOL - Step 16 (Predicting window starting 2025-04-11 16:01:00) ---
#   Training indices: [900:2339]; Testing indices: [2340:2627]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.66s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.9885
#   Step 16 finished in 1.73s total.
#
# --- SOL - Step 17 (Predicting window starting 2025-04-11 17:01:00) ---
#   Training indices: [960:2399]; Testing indices: [2400:2687]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.72s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.83}, Best CV F1: 0.9856
#   Step 17 finished in 1.78s total.
#
# --- SOL - Step 18 (Predicting window starting 2025-04-11 18:01:00) ---
#   Training indices: [1020:2459]; Testing indices: [2460:2747]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.72s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.83}, Best CV F1: 0.9866
#   Step 18 finished in 1.78s total.
#
# --- SOL - Step 19 (Predicting window starting 2025-04-11 19:01:00) ---
#   Training indices: [1080:2519]; Testing indices: [2520:2807]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.96s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.9858
#   Step 19 finished in 2.06s total.
#
# --- SOL - Step 20 (Predicting window starting 2025-04-11 20:01:00) ---
#   Training indices: [1140:2579]; Testing indices: [2580:2867]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.09s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9787
#   Step 20 finished in 2.17s total.
#
# --- SOL - Step 21 (Predicting window starting 2025-04-11 21:01:00) ---
#   Training indices: [1200:2639]; Testing indices: [2640:2927]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.18s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 9, 'n_estimators': 147, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.9834
#   Step 21 finished in 2.27s total.
#
# --- SOL - Step 22 (Predicting window starting 2025-04-11 22:01:00) ---
#   Training indices: [1260:2699]; Testing indices: [2700:2987]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.28s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 9, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9799
#   Step 22 finished in 2.37s total.
#
# --- SOL - Step 23 (Predicting window starting 2025-04-11 23:01:00) ---
#   Training indices: [1320:2759]; Testing indices: [2760:3047]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.37s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9747
#   Step 23 finished in 2.44s total.
#
# --- SOL - Step 24 (Predicting window starting 2025-04-12 00:01:00) ---
#   Training indices: [1380:2819]; Testing indices: [2820:3107]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.53s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 7, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9721
#   Step 24 finished in 2.63s total.
#
# --- SOL - Step 25 (Predicting window starting 2025-04-12 01:01:00) ---
#   Training indices: [1440:2879]; Testing indices: [2880:3167]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.57s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 9, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9772
#   Step 25 finished in 2.66s total.
#
# --- SOL - Step 26 (Predicting window starting 2025-04-12 02:01:00) ---
#   Training indices: [1500:2939]; Testing indices: [2940:3227]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.55s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.9672
#   Step 26 finished in 2.65s total.
#
# --- SOL - Step 27 (Predicting window starting 2025-04-12 03:01:00) ---
#   Training indices: [1560:2999]; Testing indices: [3000:3287]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.58s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9726
#   Step 27 finished in 2.68s total.
#
# --- SOL - Step 28 (Predicting window starting 2025-04-12 04:01:00) ---
#   Training indices: [1620:3059]; Testing indices: [3060:3347]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.60s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 7, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9737
#   Step 28 finished in 2.68s total.
#
# --- SOL - Step 29 (Predicting window starting 2025-04-12 05:01:00) ---
#   Training indices: [1680:3119]; Testing indices: [3120:3407]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.59s.
# ...
#   Step 127 finished in 1.67s total.
#
# --- SOL - Step 128 (Predicting window starting 2025-04-16 11:04:00) ---
#   Training indices: [7800:9239]; Testing indices: [9240:9527]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.62s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9601
#   Step 128 finished in 1.69s total.
#
# --- SOL - Step 129 (Predicting window starting 2025-04-16 12:04:00) ---
#   Training indices: [7860:9299]; Testing indices: [9300:9587]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.65s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.9769
#   Step 129 finished in 1.74s total.
#
# --- SOL - Step 130 (Predicting window starting 2025-04-16 13:04:00) ---
#   Training indices: [7920:9359]; Testing indices: [9360:9647]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.65s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9688
#   Step 130 finished in 1.71s total.
#
# --- SOL - Step 131 (Predicting window starting 2025-04-16 14:04:00) ---
#   Training indices: [7980:9419]; Testing indices: [9420:9707]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.62s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9809
#   Step 131 finished in 1.68s total.
#
# --- SOL - Step 132 (Predicting window starting 2025-04-16 15:04:00) ---
#   Training indices: [8040:9479]; Testing indices: [9480:9767]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.85s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9800
#   Step 132 finished in 1.92s total.
#
# --- SOL - Step 133 (Predicting window starting 2025-04-16 16:04:00) ---
#   Training indices: [8100:9539]; Testing indices: [9540:9827]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.83s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.9781
#   Step 133 finished in 1.92s total.
#
# --- SOL - Step 134 (Predicting window starting 2025-04-16 17:04:00) ---
#   Training indices: [8160:9599]; Testing indices: [9600:9887]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.81s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9753
#   Step 134 finished in 1.88s total.
#
# --- SOL - Step 135 (Predicting window starting 2025-04-16 18:04:00) ---
#   Training indices: [8220:9659]; Testing indices: [9660:9947]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.06s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 7, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9729
#   Step 135 finished in 2.14s total.
#
# --- SOL - Step 136 (Predicting window starting 2025-04-16 19:04:00) ---
#   Training indices: [8280:9719]; Testing indices: [9720:10007]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.07s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 7, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9799
#   Step 136 finished in 2.15s total.
#
# --- SOL - Step 137 (Predicting window starting 2025-04-16 20:04:00) ---
#   Training indices: [8340:9779]; Testing indices: [9780:10067]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.19s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 7, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9742
#   Step 137 finished in 2.27s total.
#
# --- SOL - Step 138 (Predicting window starting 2025-04-16 21:04:00) ---
#   Training indices: [8400:9839]; Testing indices: [9840:10127]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.15s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.26, 'subsample': 0.83}, Best CV F1: 0.9753
#   Step 138 finished in 2.23s total.
#
# --- SOL - Step 139 (Predicting window starting 2025-04-16 22:04:00) ---
#   Training indices: [8460:9899]; Testing indices: [9900:10187]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.18s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9813
#   Step 139 finished in 2.26s total.
#
# --- SOL - Step 140 (Predicting window starting 2025-04-16 23:04:00) ---
#   Training indices: [8520:9959]; Testing indices: [9960:10247]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.14s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.9782
#   Step 140 finished in 2.22s total.
#
# --- SOL - Step 141 (Predicting window starting 2025-04-17 00:04:00) ---
#   Training indices: [8580:10019]; Testing indices: [10020:10307]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.13s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.83}, Best CV F1: 0.9736
#   Step 141 finished in 2.22s total.
#
# --- SOL - Step 142 (Predicting window starting 2025-04-17 01:04:00) ---
#   Training indices: [8640:10079]; Testing indices: [10080:10367]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.22s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 9, 'n_estimators': 147, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.9797
#   Step 142 finished in 2.33s total.
#
# --- SOL - Step 143 (Predicting window starting 2025-04-17 02:04:00) ---
#   Training indices: [8700:10139]; Testing indices: [10140:10427]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.15s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9773
#   Step 143 finished in 2.22s total.
#
# --- SOL - Step 144 (Predicting window starting 2025-04-17 03:04:00) ---
#   Training indices: [8760:10199]; Testing indices: [10200:10487]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.20s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 7, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9773
#   Step 144 finished in 2.28s total.
#
# --- SOL - Step 145 (Predicting window starting 2025-04-17 04:04:00) ---
#   Training indices: [8820:10259]; Testing indices: [10260:10547]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.38s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.9778
#   Step 145 finished in 2.47s total.
#
# --- SOL - Step 146 (Predicting window starting 2025-04-17 05:04:00) ---
#   Training indices: [8880:10319]; Testing indices: [10320:10607]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.38s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 9, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9776
#   Step 146 finished in 2.48s total.
#
# --- SOL - Step 147 (Predicting window starting 2025-04-17 06:04:00) ---
#   Training indices: [8940:10379]; Testing indices: [10380:10667]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.31s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.9793
#   Step 147 finished in 2.37s total.
#
# --- SOL - Step 148 (Predicting window starting 2025-04-17 07:04:00) ---
#   Training indices: [9000:10439]; Testing indices: [10440:10727]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.30s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.83}, Best CV F1: 0.9850
#   Step 148 finished in 2.37s total.
#
# --- SOL - Step 149 (Predicting window starting 2025-04-17 08:04:00) ---
#   Training indices: [9060:10499]; Testing indices: [10500:10787]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.25s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9804
#   Step 149 finished in 2.35s total.
#
# --- SOL - Step 150 (Predicting window starting 2025-04-17 09:04:00) ---
#   Training indices: [9120:10559]; Testing indices: [10560:10847]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.22s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 9, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9810
#   Step 150 finished in 2.33s total.
#
# --- SOL - Step 151 (Predicting window starting 2025-04-17 10:04:00) ---
#   Training indices: [9180:10619]; Testing indices: [10620:10907]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.21s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 7, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9788
#   Step 151 finished in 2.31s total.
#
# --- SOL - Step 152 (Predicting window starting 2025-04-17 11:04:00) ---
#   Training indices: [9240:10679]; Testing indices: [10680:10967]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.19s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9803
#   Step 152 finished in 2.29s total.
#
# --- SOL - Step 153 (Predicting window starting 2025-04-17 12:04:00) ---
#   Training indices: [9300:10739]; Testing indices: [10740:11027]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.09s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.26, 'subsample': 0.83}, Best CV F1: 0.9725
#   Step 153 finished in 2.18s total.
#
# --- SOL - Step 154 (Predicting window starting 2025-04-17 13:04:00) ---
#   Training indices: [9360:10799]; Testing indices: [10800:11087]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.01s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 7, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9676
#   Step 154 finished in 2.10s total.
#
# --- SOL - Step 155 (Predicting window starting 2025-04-17 14:04:00) ---
#   Training indices: [9420:10859]; Testing indices: [10860:11147]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.98s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9606
#   Step 155 finished in 2.08s total.
#
# --- SOL - Step 156 (Predicting window starting 2025-04-17 15:04:00) ---
#   Training indices: [9480:10919]; Testing indices: [10920:11207]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 2.03s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 7, 'n_estimators': 147, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.9595
#   Step 156 finished in 2.11s total.
#
# --- SOL - Step 157 (Predicting window starting 2025-04-17 16:04:00) ---
#   Training indices: [9540:10979]; Testing indices: [10980:11267]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.94s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9589
#   Step 157 finished in 2.05s total.
#
# --- SOL - Step 158 (Predicting window starting 2025-04-17 17:04:00) ---
#   Training indices: [9600:11039]; Testing indices: [11040:11327]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.98s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9629
#   Step 158 finished in 2.06s total.
#
# --- SOL - Step 159 (Predicting window starting 2025-04-17 18:04:00) ---
#   Training indices: [9660:11099]; Testing indices: [11100:11387]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.95s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.9360
#   Step 159 finished in 2.02s total.
#
# --- SOL - Step 160 (Predicting window starting 2025-04-17 19:04:00) ---
#   Training indices: [9720:11159]; Testing indices: [11160:11447]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.84s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 7, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9465
#   Step 160 finished in 1.92s total.
#
# --- SOL - Step 161 (Predicting window starting 2025-04-17 20:04:00) ---
#   Training indices: [9780:11219]; Testing indices: [11220:11507]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.71s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 7, 'n_estimators': 147, 'reg_alpha': 0.26, 'subsample': 0.83}, Best CV F1: 0.9084
#   Step 161 finished in 1.80s total.
#
# --- SOL - Step 162 (Predicting window starting 2025-04-17 21:04:00) ---
#   Training indices: [9840:11279]; Testing indices: [11280:11567]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.67s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.26, 'subsample': 0.92}, Best CV F1: 0.9171
#   Step 162 finished in 1.74s total.
#
# --- SOL - Step 163 (Predicting window starting 2025-04-17 22:04:00) ---
#   Training indices: [9900:11339]; Testing indices: [11340:11627]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.71s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.26, 'subsample': 0.83}, Best CV F1: 0.9365
#   Step 163 finished in 1.78s total.
#
# --- SOL - Step 164 (Predicting window starting 2025-04-17 23:04:00) ---
#   Training indices: [9960:11399]; Testing indices: [11400:11687]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.65s.
#   Best Params: {'colsample_bytree': 0.72, 'max_depth': 6, 'n_estimators': 147, 'reg_alpha': 0.14, 'subsample': 0.92}, Best CV F1: 0.9355
#   Step 164 finished in 1.73s total.
#
# --- SOL - Step 165 (Predicting window starting 2025-04-18 00:04:00) ---
#   Training indices: [10020:11459]; Testing indices: [11460:11747]
#   Running GridSearchCV (cv=3, scoring='f1')...
#   GridSearchCV finished in 1.65s.
#   Best Params: {'colsample_bytree': 0.68, 'max_depth': 6, 'n_estimators': 112, 'reg_alpha': 0.14, 'subsample': 0.83}, Best CV F1: 0.9212
#   Step 165 finished in 1.70s total.
#
# Backtesting loop for SOL finished. Completed 165 steps (each predicting up to 288 points) in 5.14 minutes.
#
# --- Evaluating Results for SOL with Probability Threshold Tuning ---
# Threshold search range: [0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65 0.7  0.75
#  0.8  0.85]
#
# Best Threshold for SOL found: 0.15 (Yielding F1 Score: 0.6758)
#
# --- Final Performance Metrics for SOL (Optimized Threshold) ---
# Target: 720m return >= 2.5%
# Windowing: Train=1440m, Step=60m, Test Window=288m
# Total Individual Predictions Evaluated: 47520
# Overall Accuracy:  0.7940
# Overall Precision: 0.6153
# Overall Recall:    0.7496
# Overall F1 Score:  0.6758
# (Compare: Default 0.5 Thresh -> F1:0.6541, Acc:0.8159, Pre:0.7082, Rec:0.6077)
#
# Plotting cumulative accuracy for SOL (optimized threshold)...
# Saved accuracy plot to backtest_accuracy_SOL.png
#
# Finished processing SOL in 5.15 minutes.
#
# ============================== Overall Script Finished ==============================
# Total execution time: 7.06 minutes.

# %%
X.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'Volume BTC', 'Volume USD',
#        'price_range_pct', 'oc_change_pct', 'garman_klass_12h', 'parkinson_3h',
#        'ma_3h', 'rolling_std_3h', 'lag_3h_price_return', 'lag_6h_price_return',
#        'lag_12h_price_return', 'lag_24h_price_return', 'lag_48h_price_return',
#        'lag_72h_price_return', 'lag_168h_price_return', 'volume_return_1h',
#        'lag_3h_volume_return', 'lag_6h_volume_return', 'lag_12h_volume_return',
#        'lag_24h_volume_return', 'ma_6h', 'ma_12h', 'ma_24h', 'ma_48h',
#        'ma_72h', 'ma_168h', 'rolling_std_6h', 'rolling_std_12h',
#        'rolling_std_24h', 'rolling_std_48h', 'rolling_std_72h',
#        'rolling_std_168h', 'atr_14h', 'atr_24h', 'atr_48h', 'close_div_ma_24h',
#        'close_div_ma_48h', 'close_div_ma_168h', 'ma12_div_ma48',
#        'ma24_div_ma168', 'std12_div_std72', 'volume_btc_x_range',
#        'rolling_std_3h_sq', 'price_return_1h_sq', 'rolling_std_12h_sqrt'],
#       dtype='object')

# %% [markdown]
# What Now?
#
# This is great progress! It tells you that predicting 12-hour direction is a much more promising path with your data and feature types.
#
# Stick with the Simpler Structure (for now): Keep the single model (XGBoost) and the expanding window backtest for now.
#
# Optimize This Setup:
#
# Apply VIF: Now that you have a working model structure and a seemingly viable target, apply VIF filtering (e.g., threshold 5 or even your strict 1.69) to the features generated in this simpler script. Does reducing collinearity now improve the already decent results?
#
# Tune Hyperparameters: Tune the XGBoost parameters (n_estimators, max_depth, learning_rate, reg_alpha, reg_lambda, subsample, colsample_bytree, min_child_weight) using a method like Optuna or RandomizedSearchCV within the rolling backtest loop (similar to how the meta-learner was tuned, but now for the single main model).
#
# Experiment with Target Horizon: Is 12 hours optimal for the >0% target? Try 8 hours, 24 hours.
#
# Experiment with Training Window: Does the expanding window work best, or would a large sliding window perform better for this target?
#
# You've found a much better baseline. Now optimize it systematically!
